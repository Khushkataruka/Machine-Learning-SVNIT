# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushkataruka/Machine-Learning-SVNIT/blob/main/LAB1_Advertisement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Advertising** **Dataset**

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# @title Sales

from matplotlib import pyplot as plt
df['Sales'].plot(kind='hist', bins=20, title='Sales')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Newspaper

from matplotlib import pyplot as plt
df['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
x=df.drop('Sales',axis=1)
y=df['Sales']

# %%
#x and y must be numpy array
def Linear_Regression(x,y,learning_rate):
  weights=np.zeros((1,x.shape[1]))
  bias=0
  learning_rate=learning_rate
  epochs=1000
  for i in range(epochs):
    y_pred=np.dot(weights,x.T)+bias #(1,200
    print(y.shape,y_pred.shape)
    loss=np.mean((y-y_pred)**2)
    dw=2*(y_pred-y).dot(x)
    db=2*(y_pred-y)
    weights=weights-learning_rate*dw
    bias=bias-learning_rate*db
    print(f"Loss:{loss},Epoch:{i}\n{'-'*50}\n")
  return weights,bias

# %%
y=np.array(y)
y=y.T
x=np.array(x)
w,b=Linear_Regression(x,y)
print(w.shape,b.shape)
# Out:
# Loss:256.71195,Epoch:0
# --------------------------------------------------
#
# Loss:24.481393762413568,Epoch:1
# --------------------------------------------------
#
# Loss:14.297754778707487,Epoch:2
# --------------------------------------------------
#
# Loss:13.515930750415146,Epoch:3
# --------------------------------------------------
#
# Loss:13.15133397781441,Epoch:4
# --------------------------------------------------
#
# Loss:12.823182898447453,Epoch:5
# --------------------------------------------------
#
# Loss:12.514243466136064,Epoch:6
# --------------------------------------------------
#
# Loss:12.22271117421541,Epoch:7
# --------------------------------------------------
#
# Loss:11.94750021152656,Epoch:8
# --------------------------------------------------
#
# Loss:11.687617822673142,Epoch:9
# --------------------------------------------------
#
# Loss:11.442133964556541,Epoch:10
# --------------------------------------------------
#
# ...

# %%
def predict(x,w,b):
  x=np.array(x)
  y_pred=np.dot(w,x.T)+b
  return y_pred

# %%
b=np.mean(b)

# %%
predict([238,37,70],w,b)
# Out:
# array([23.87698413])

# %% [markdown]
# **Housing** **Dataset**

# %%
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.head()
# Out:
#     price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  133.00  7420         4          2        3       NaN        NaN       NaN
# 1  122.50  8960         4          4        4       NaN        NaN       NaN
# 2  122.50  9960         3          2        2       NaN        NaN       NaN
# 3  122.15  7500         4          2        2       NaN        NaN       NaN
# 4  114.10  7420         4          1        2       NaN        NaN       NaN
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0              NaN              NaN        2       NaN               NaN
# 1              NaN              NaN        3       NaN               NaN
# 2              NaN              NaN        2       NaN               NaN
# 3              NaN              NaN        3       NaN               NaN
# 4              NaN              NaN        2       NaN               NaN

# %%
x=np.array(df.drop('price',axis=1))
y=np.array(df['price'])
print(x.shape,y.shape)
# Out:
# (545, 12) (545,)

# %%
w,b=Linear_Regression(x,y,learning_rate=1e-10)
# Out:
# (545,) (1, 545)
# Loss:nan,Epoch:0
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:1
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:2
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:3
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:4
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:5
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:6
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:7
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:8
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:9
# --------------------------------------------------
#
# (545,) (1, 545)
# Loss:nan,Epoch:10
# ...
